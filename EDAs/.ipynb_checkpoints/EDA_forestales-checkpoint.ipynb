# %% [markdown]
# Debido al hecho de que GitHub realiza una representación estática de los cuadernos y no incluye el HTML/JavaScript incrustado que forma un gráfico de trama, y teniendo en cuenta que para presentar la información de una forma más amena e interactiva se hizo uso de la librería Plotly de Python la cual crea este tipo de gráficas combinadas con HTML, no es posible verlas directamente en este Notebook, por lo que le invitamos a observar este mismo Notebook de forma renderizada en el link de [acá](https://colab.research.google.com/drive/1rGd8SbDYtkVTEmiLIJs8UJtmemvyqUlT?usp=sharing) el cual es un Gooogle Colab con el código que le permitirá interactuar con el mismo

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('Base_de_datos_relacionada_con_area_plantada_con_Plantaciones_Forestales_Comerciales.csv')

# %%
df
# Out:
#           Departamento        Sistema Siembra     Nombre Cientifico  \
# 0               BOYACÁ    Plantación Forestal  Cupressus lusitanica
# 1               BOYACÁ    Plantación Forestal          Pinus pátula
# 2               BOYACÁ    Plantación Forestal          Pinus pátula
# 3      VALLE DEL CAUCA    Plantación Forestal    Eucalyptus grandis
# 4                CAUCA    Plantación Forestal    Eucalyptus grandis
# ...                ...                    ...                   ...
# 31098            SUCRE  Sistemas Agroforestal      Cordia alliodora
# 31099           TOLIMA  Sistemas Agroforestal      Cordia alliodora
# 31100  VALLE DEL CAUCA  Sistemas Agroforestal      Cordia alliodora
# 31101           VAUPÉS  Sistemas Agroforestal      Cordia alliodora
# 31102          VICHADA  Sistemas Agroforestal      Cordia alliodora
#
#       Agrupacion por Especies Reforestacion Comercial Agrupacion por Origen  \
# 0                                              Cipres   Especie Introducida
# 1                                         Pino pátula   Especie Introducida
# 2                                         Pino pátula   Especie Introducida
# 3                                   Eucalipto Grandis   Especie Introducida
# 4                                   Eucalipto Grandis   Especie Introducida
# ...                                               ...                   ...
# 31098                                           Nogal        Especie Nativa
# 31099                                           Nogal        Especie Nativa
# 31100                                           Nogal        Especie Nativa
# 31101                                           Nogal        Especie Nativa
# 31102                                           Nogal        Especie Nativa
#
#           Nombre Comun  Año de Establecimiento Modo Siembra  SubRegión  \
# 0               Cipres                    1989      Arboles     ANDINA
# 1        Pino mexicano                    1989      Arboles     ANDINA
# 2        Pino mexicano                    1979    Hectáreas     ANDINA
# 3      Eucalipto comùn                    1993    Hectáreas   PACÍFICO
# 4      Eucalipto comùn                    1996    Hectáreas   PACÍFICO
# ...                ...                     ...          ...        ...
# 31098   Nogal cafetero                    2021    Hectáreas     CARIBE
# 31099   Nogal cafetero                    2021    Hectáreas     ANDINA
# 31100   Nogal cafetero                    2021    Hectáreas   PACÍFICO
# 31101   Nogal cafetero                    2021    Hectáreas   AMAZONÍA
# 31102   Nogal cafetero                    2021    Hectáreas  ORINOQUÍA
#
#                           Zona UPRA  Hectareas (Ha) Fuente de Información
# 0                             OTROS             4.5                  MADR
# 1                             OTROS             2.7                  MADR
# 2                             OTROS             4.0                  MADR
# 3      EJE CAFETERO Y SUR OCCIDENTE             0.3                  MADR
# 4      EJE CAFETERO Y SUR OCCIDENTE            30.0                  MADR
# ...                             ...             ...                   ...
# 31098                         OTROS             0.0                  MADR
# 31099                         OTROS             3.0                  MADR
# 31100  EJE CAFETERO Y SUR OCCIDENTE             2.3                  MADR
# 31101                         OTROS             0.0                  MADR
# 31102                     ORINOQUÍA             0.0                  MADR
#
# [31103 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31103 entries, 0 to 31102
# Data columns (total 12 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Departamento                                     31103 non-null  object
#  1   Sistema Siembra                                  31103 non-null  object
#  2   Nombre Cientifico                                31103 non-null  object
#  3   Agrupacion por Especies Reforestacion Comercial  31103 non-null  object
#  4   Agrupacion por Origen                            31103 non-null  object
#  5   Nombre Comun                                     12548 non-null  object
#  6   Año de Establecimiento                           31103 non-null  int64
#  7   Modo Siembra                                     31103 non-null  object
#  8   SubRegión                                        31103 non-null  object
#  9   Zona UPRA                                        31103 non-null  object
#  10  Hectareas (Ha)                                   31103 non-null  float64
#  11  Fuente de Información                            31103 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#        Año de Establecimiento  Hectareas (Ha)
# count            31103.000000    31103.000000
# mean              2005.667106       17.323818
# std                 12.490286       57.833340
# min               1960.000000       -2.600000
# 25%               1999.000000        0.500000
# 50%               2008.000000        2.100000
# 75%               2015.000000       11.900000
# max               2022.000000     2468.000000

# %%
# Distribución de área plantada por departamento
fig = px.bar(
    df.groupby("Departamento")['Hectareas (Ha)'].sum().reset_index(),
    x='Departamento',
    y='Hectareas (Ha)',
    title="Área Plantada por Departamento"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8b56dae0-1555-41b4-a93c-4845efff84bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b56dae0-1555-41b4-a93c-4845efff84bf")) {                    Plotly.newPlot(                        "8b56dae0-1555-41b4-a93c-4845efff84bf",                        [{"alignmentgroup":"True","hovertemplate":"Departamento=%{x}\u003cbr\u003eHectareas (Ha)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["AMAZONAS","ANTIOQUIA","ARAUCA","ATLÁNTICO","Antioquia","BOLÍVAR","BOYACÁ","Bolívar","CALDAS","CAQUETÁ","CASANARE","CAUCA","CESÁR","CHOCÓ","CUNDINAMARCA","Caldas","Casanare","CÓRDOBA","Córdoba","GUAINÍA","GUAJIRA","GUAVIARE","HUILA","MAGDALENA","META","Meta","NARIÑO","NORTE DE SANTANDER","PUTUMAYO","QUINDÍO","RISARALDA","Risaralda","SANTANDER","SUCRE","Santander","Sucre","TOLIMA","VALLE DEL CAUCA","VAUPÉS","VICHADA","Vichada"],"xaxis":"x","y":[0.3,116191.9,609.9,2206.3,464.40000000000003,11727.6,6185.9,130.9,29233.1,600.8,6642.7,25940.9,9606.5,1126.6,9809.2,109.4,550.7,35976.3,167.2,4.5,701.4,378.6,12015.2,15218.5,63638.2,1026.0,1405.6,1534.1,194.6,5952.4,10511.8,37.5,20418.3,5589.4,6.8,37.0,9313.0,27285.9,0.5,104931.6,1341.2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777 ...

# %%
# Agrupar por departamento y calcular el total de hectáreas
hectareas_por_departamento = df.groupby('Departamento')['Hectareas (Ha)'].sum().reset_index()

# Obtener los 5 departamentos con mayor cantidad de hectáreas
top_5_departamentos = hectareas_por_departamento.nlargest(5, 'Hectareas (Ha)')

# Filtrar los datos para solo los 5 departamentos seleccionados
df_top_5_departamentos = df[df['Departamento'].isin(top_5_departamentos['Departamento'])]

# Agrupar por departamento, especies y origen y calcular la suma de hectáreas
hectareas_por_especies_origen = df_top_5_departamentos.groupby(['Departamento', 'Agrupacion por Especies Reforestacion Comercial', 'Agrupacion por Origen'])['Hectareas (Ha)'].sum().reset_index()

# %%
hectareas_por_especies_introducida = hectareas_por_especies_origen[hectareas_por_especies_origen['Agrupacion por Origen'] == 'Especie Introducida']
#Crear el gráfico de barras apiladas
fig = px.bar(hectareas_por_especies_introducida,
             x='Departamento',
             y='Hectareas (Ha)',
             color='Agrupacion por Especies Reforestacion Comercial',
             facet_col='Agrupacion por Origen',
             title='Cantidad de Hectáreas por Especies y Origen en los 5 Departamentos con Mayor Área Plantada',
             labels={'Hectareas (Ha)': 'Cantidad de Hectáreas', 'Agrupacion por Especies Reforestacion Comercial': 'Especies', 'Agrupacion por Origen': 'Origen'},
             barmode='stack')

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="212df34c-42c0-4753-97c5-8965c3e5f463" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("212df34c-42c0-4753-97c5-8965c3e5f463")) {                    Plotly.newPlot(                        "212df34c-42c0-4753-97c5-8965c3e5f463",                        [{"alignmentgroup":"True","hovertemplate":"Especies=Acacia mangium\u003cbr\u003eOrigen=Especie Introducida\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Acacia mangium","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Acacia mangium","offsetgroup":"Acacia mangium","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","CÓRDOBA","META","VICHADA"],"xaxis":"x","y":[7833.7,21.3,8725.4,16357.4,31056.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Cedro\u003cbr\u003eOrigen=Especie Introducida\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cedro","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cedro","offsetgroup":"Cedro","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA"],"xaxis":"x","y":[140.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Cipres\u003cbr\u003eOrigen=Especie Introducida\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cipres","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cipres","offsetgroup":"Cipres","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS"],"xaxis":"x","y":[5069.1,2837.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Eucalipto Globulus\u003cbr\u003eOrigen=Especie Introducida\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eucalipto Globulus","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Eucalipto Globulus","offsetgroup":"Eucalipto Globulus","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS"],"xaxis":"x","y":[3.2,50.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Eucalipto Grandis\u003cbr\u003eOrigen=Especie Introducida\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eucalipto Grandis","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Eucalipto Grandis","offsetgroup":"Eucalipto Grandis","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","META","VICHADA"],"xaxis":"x","y":[6963.1,3783.8,0.3,73.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Eucalipto Pellita\u003cbr\u003eOrigen=Especie Introducida\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eucalipto Pellita","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Eucalipto Pellita","offsetgroup":"Eucalipto Pellita","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","CÓRDOBA","META","VICHADA"],"xaxis":"x","y":[585.1,1.3,722.3,13473.8,17036.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Eucalipto camaldulensis\u003cbr\u003eOrigen=Especie Introducida\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eucalipto camaldulensis","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Eucalipto camaldulensis","offsetgroup":"Eucali ...

# %%
hectareas_por_especies_nativa = hectareas_por_especies_origen[hectareas_por_especies_origen['Agrupacion por Origen'] == 'Especie Nativa']
#Crear el gráfico de barras apiladas
fig = px.bar(hectareas_por_especies_nativa,
             x='Departamento',
             y='Hectareas (Ha)',
             color='Agrupacion por Especies Reforestacion Comercial',
             facet_col='Agrupacion por Origen',
             title='Cantidad de Hectáreas por Especies y Origen en los 5 Departamentos con Mayor Área Plantada',
             labels={'Hectareas (Ha)': 'Cantidad de Hectáreas', 'Agrupacion por Especies Reforestacion Comercial': 'Especies', 'Agrupacion por Origen': 'Origen'},
             barmode='stack')

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="153a10c5-4d46-465b-8e5c-470ad73aac42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("153a10c5-4d46-465b-8e5c-470ad73aac42")) {                    Plotly.newPlot(                        "153a10c5-4d46-465b-8e5c-470ad73aac42",                        [{"alignmentgroup":"True","hovertemplate":"Especies=Balso\u003cbr\u003eOrigen=Especie Nativa\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Balso","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Balso","offsetgroup":"Balso","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","CÓRDOBA"],"xaxis":"x","y":[463.0,15.4,1.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Caucho\u003cbr\u003eOrigen=Especie Nativa\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Caucho","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Caucho","offsetgroup":"Caucho","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","CÓRDOBA","META","VICHADA"],"xaxis":"x","y":[983.7,698.6,133.5,21347.1,10270.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Cedro\u003cbr\u003eOrigen=Especie Nativa\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cedro","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cedro","offsetgroup":"Cedro","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","CÓRDOBA","META","VICHADA"],"xaxis":"x","y":[2539.6,67.2,595.5,164.3,58.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Ceiba\u003cbr\u003eOrigen=Especie Nativa\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ceiba","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Ceiba","offsetgroup":"Ceiba","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CÓRDOBA","META","VICHADA"],"xaxis":"x","y":[609.8000000000001,2473.1,188.6,11.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Nogal\u003cbr\u003eOrigen=Especie Nativa\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nogal","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Nogal","offsetgroup":"Nogal","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","CÓRDOBA","META","VICHADA"],"xaxis":"x","y":[3232.3,2052.6,183.4,60.99999999999999,142.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Otras Nativas\u003cbr\u003eOrigen=Especie Nativa\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Otras Nativas","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Otras Nativas","offsetgroup":"Otras Nativas","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","CÓRDOBA","META","VICHADA"],"xaxis":"x","y":[3700.6,1192.3,4164.0,1023.7,625.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Especies=Roble\u003cbr\u003eOrigen=Especie Nativa\u003cbr\u003eDepartamento=%{x}\u003cbr\u003eCantidad de Hectáreas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Roble","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Roble","offsetgroup":"Roble","orientation":"v","showlegend":true,"textposition":"auto","x":["ANTIOQUIA","CALDAS","CÓRDOBA" ...

# %%
hectareas_por_especies_introducida
# Out:
#     Departamento Agrupacion por Especies Reforestacion Comercial  \
# 0      ANTIOQUIA                                  Acacia mangium
# 3      ANTIOQUIA                                           Cedro
# 6      ANTIOQUIA                                          Cipres
# 7      ANTIOQUIA                              Eucalipto Globulus
# 8      ANTIOQUIA                               Eucalipto Grandis
# ..           ...                                             ...
# 96       VICHADA                                    Pino oocarpa
# 97       VICHADA                                     Pino pátula
# 98       VICHADA                                Pino tecunumanii
# 99       VICHADA                                  Pinus caribaea
# 100      VICHADA                                            Teca
#
#     Agrupacion por Origen  Hectareas (Ha)
# 0     Especie Introducida          7833.7
# 3     Especie Introducida           140.8
# 6     Especie Introducida          5069.1
# 7     Especie Introducida             3.2
# 8     Especie Introducida          6963.1
# ..                    ...             ...
# 96    Especie Introducida            70.4
# 97    Especie Introducida          1000.0
# 98    Especie Introducida            60.1
# 99    Especie Introducida         40035.0
# 100   Especie Introducida           890.5
#
# [68 rows x 4 columns]

# %%
# Total de Hectáreas por Especies Reforestacion Comercial"
hectareas_especies = df.groupby('Agrupacion por Especies Reforestacion Comercial')['Hectareas (Ha)'].sum().reset_index()
fig = px.bar(hectareas_especies, x='Agrupacion por Especies Reforestacion Comercial', y='Hectareas (Ha)', title='Total de Hectáreas por Especies Reforestación Comercial')
fig.update_layout(xaxis_title='Agrupación por Especies', yaxis_title='Hectáreas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="233741d9-b635-454e-9262-7a2e848202ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("233741d9-b635-454e-9262-7a2e848202ed")) {                    Plotly.newPlot(                        "233741d9-b635-454e-9262-7a2e848202ed",                        [{"alignmentgroup":"True","hovertemplate":"Agrupacion por Especies Reforestacion Comercial=%{x}\u003cbr\u003eHectareas (Ha)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Acacia mangium","Balso","Caucho","Cedro","Ceiba","Cipres","Eucalipto Globulus","Eucalipto Grandis","Eucalipto Pellita","Eucalipto camaldulensis","Eucalipto tereticornis","Eucalipto urophylla","Melina","Nogal","Otras Introducidas","Otras Nativas","Otros Eucaliptos","Otros Pinos","Pino maximinoi","Pino oocarpa","Pino pátula","Pino tecunumanii","Pinus caribaea","Roble","Teca","n.d."],"xaxis":"x","y":[67734.5,1259.8,36280.8,6484.4,10226.8,9968.3,8868.3,42394.0,35518.5,2678.8,10152.0,15973.2,18028.2,16622.6,202.6,20967.0,3029.2,3459.2,17058.7,16200.6,59805.2,32402.9,50074.5,11001.9,40288.6,2142.1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar ...

# %%
# Total de Hectáreas por "Agrupacion por Origen"
hectareas_origen = df.groupby('Agrupacion por Origen')['Hectareas (Ha)'].sum().reset_index()
fig = px.bar(hectareas_origen, x='Agrupacion por Origen', y='Hectareas (Ha)', title='Total de Hectáreas por Agrupación por Origen')
fig.update_layout(xaxis_title='Agrupación por Origen', yaxis_title='Hectáreas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1eabee60-5988-415d-835c-357e5ad90dc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1eabee60-5988-415d-835c-357e5ad90dc8")) {                    Plotly.newPlot(                        "1eabee60-5988-415d-835c-357e5ad90dc8",                        [{"alignmentgroup":"True","hovertemplate":"Agrupacion por Origen=%{x}\u003cbr\u003eHectareas (Ha)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Especie Introducida","Especie Nativa","Otras Nativas","n.d."],"xaxis":"x","y":[434120.7,102552.0,7.8999999999999995,2142.1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"s ...

# %%
# Total de Hectáreas por Año de Establecimiento
hectareas_por_anio = df.groupby('Año de Establecimiento')['Hectareas (Ha)'].sum().reset_index()
fig = px.bar(hectareas_por_anio, x='Año de Establecimiento', y='Hectareas (Ha)', title='Total de Hectáreas por Año de Establecimiento')
fig.update_layout(xaxis_title='Año de Establecimiento', yaxis_title='Hectáreas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e13f0be2-b8ed-42b6-a1e4-4846250d865f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e13f0be2-b8ed-42b6-a1e4-4846250d865f")) {                    Plotly.newPlot(                        "e13f0be2-b8ed-42b6-a1e4-4846250d865f",                        [{"alignmentgroup":"True","hovertemplate":"Año de Establecimiento=%{x}\u003cbr\u003eHectareas (Ha)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[183.1,1.2,47.6,5.7,73.0,84.5,6.5,11.0,14.1,49.2,689.9,95.2,383.3,98.8,275.6,871.5,149.5,185.4,379.7,593.2,2173.5,2527.8,2697.3,2101.8,1601.9,1802.1,1146.7,1753.0,1352.1,1901.5,4055.5,1960.9999999999998,1931.9,2014.0,3036.7,4973.4,6366.6,7306.2,8146.7,11061.5,12879.8,9295.1,9063.9,10602.1,21819.6,18426.2,23632.6,26381.0,36163.4,30517.3,34792.6,31202.0,34465.4,31659.2,29988.1,21826.5,22123.4,14541.6,16575.8,12403.4,8537.7,7406.2,410.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0. ...

# %%
# Total de Hectáreas por SubRegión
hectareas_por_subregion = df.groupby('SubRegión')['Hectareas (Ha)'].sum().reset_index()
fig = px.bar(hectareas_por_subregion, x='SubRegión', y='Hectareas (Ha)', title='Total de Hectáreas por SubRegión')
fig.update_layout(xaxis_title='SubRegión', yaxis_title='Hectáreas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ae8eeead-7a00-47c3-b84c-1bcc04e42067" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae8eeead-7a00-47c3-b84c-1bcc04e42067")) {                    Plotly.newPlot(                        "ae8eeead-7a00-47c3-b84c-1bcc04e42067",                        [{"alignmentgroup":"True","hovertemplate":"SubRegión=%{x}\u003cbr\u003eHectareas (Ha)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["AMAZONÍA","ANDINA","CARIBE","ORINOQUÍA","PACÍFICO"],"xaxis":"x","y":[1179.3,221783.0,81361.1,178740.3,55759.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scat ...

# %%
# Total de Hectáreas por Zona UPRA
hectareas_por_zona_upra = df.groupby('Zona UPRA')['Hectareas (Ha)'].sum().reset_index()
fig = px.bar(hectareas_por_zona_upra, x='Zona UPRA', y='Hectareas (Ha)', title='Total de Hectáreas por Zona UPRA')
fig.update_layout(xaxis_title='Zona UPRA', yaxis_title='Hectáreas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f354dfc-51f6-4548-ad01-307dc067430f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f354dfc-51f6-4548-ad01-307dc067430f")) {                    Plotly.newPlot(                        "5f354dfc-51f6-4548-ad01-307dc067430f",                        [{"alignmentgroup":"True","hovertemplate":"Zona UPRA=%{x}\u003cbr\u003eHectareas (Ha)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["CARIBE","EJE CAFETERO Y SUR OCCIDENTE","ORINOQUÍA","OTROS"],"xaxis":"x","y":[75033.3,215727.3,170937.0,77125.1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"sca ...
